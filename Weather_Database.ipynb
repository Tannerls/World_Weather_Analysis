# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy import stats

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32630e5cfe13c73fe86094f397777ada

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | aykhal
# Processing Record 5 of Set 1 | emba
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | pervomayskoye
# Processing Record 9 of Set 1 | ormara
# Processing Record 10 of Set 1 | pekalongan
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | necochea
# Processing Record 15 of Set 1 | cidreira
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | nouakchott
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | port-cartier
# Processing Record 21 of Set 1 | carutapera
# Processing Record 22 of Set 1 | nelson bay
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | jiuquan
# Processing Record 26 of Set 1 | choucheng
# City not found. Skipping...
# Processing Record 27 of Set 1 | narsaq
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | joshimath
# Processing Record 31 of Set 1 | samarinda
# Processing Record 32 of Set 1 | pasighat
# Processing Record 33 of Set 1 | polovinnoye
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | mega
# Processing Record 38 of Set 1 | dabakala
# Processing Record 39 of Set 1 | taltal
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | umm lajj
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | guerrero negro
# Processing Record 44 of Set 1 | melita
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | agadez
# Processing Record 49 of Set 1 | dingle
# Processing Record 50 of Set 1 | broome
# Processing Record 1 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 2 | port hardy
# Processing Record 3 of Set 2 | dunedin
# Processing Record 4 of Set 2 | taoudenni
# Processing Record 5 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 2 | luganville
# Processing Record 7 of Set 2 | nagar karnul
# Processing Record 8 of Set 2 | vila
# Processing Record 9 of Set 2 | berlevag
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | pendleton
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | greenville
# Processing Record 14 of Set 2 | carnarvon
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | aguilas
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | marmarion
# Processing Record 21 of Set 2 | hovd
# Processing Record 22 of Set 2 | pevek
# Processing Record 23 of Set 2 | bethel
# Processing Record 24 of Set 2 | ixtapa
# Processing Record 25 of Set 2 | sitka
# Processing Record 26 of Set 2 | mogadishu
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | kloulklubed
# Processing Record 29 of Set 2 | nan
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | russell
# Processing Record 34 of Set 2 | poum
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | kieta
# Processing Record 37 of Set 2 | saint-pierre
# Processing Record 38 of Set 2 | honiara
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | yangambi
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | coahuayana
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | isangel
# Processing Record 47 of Set 2 | skjervoy
# Processing Record 48 of Set 2 | toftir
# City not found. Skipping...
# Processing Record 49 of Set 2 | seymchan
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | meulaboh
# Processing Record 2 of Set 3 | viransehir
# Processing Record 3 of Set 3 | batagay-alyta
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | shahr-e babak
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | blyth
# Processing Record 8 of Set 3 | seoul
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | okakarara
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | tacuati
# Processing Record 13 of Set 3 | kaduna
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | mount gambier
# Processing Record 16 of Set 3 | korem
# Processing Record 17 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 3 | tual
# Processing Record 19 of Set 3 | lotoshino
# Processing Record 20 of Set 3 | fort nelson
# Processing Record 21 of Set 3 | khatanga
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | shache
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | madang
# Processing Record 27 of Set 3 | northam
# Processing Record 28 of Set 3 | fukagawa
# Processing Record 29 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 3 | dakar
# Processing Record 31 of Set 3 | jamestown
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | tarauaca
# Processing Record 34 of Set 3 | awjilah
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | fare
# Processing Record 37 of Set 3 | palmeira das missoes
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | harper
# Processing Record 41 of Set 3 | henties bay
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | praia da vitoria
# Processing Record 44 of Set 3 | baduria
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | mayo
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | tubuala
# Processing Record 49 of Set 3 | viedma
# Processing Record 50 of Set 3 | xinye
# Processing Record 1 of Set 4 | norrtalje
# Processing Record 2 of Set 4 | jalu
# Processing Record 3 of Set 4 | kiknur
# Processing Record 4 of Set 4 | romny
# Processing Record 5 of Set 4 | ambatondrazaka
# Processing Record 6 of Set 4 | aswan
# Processing Record 7 of Set 4 | esperance
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | te anau
# Processing Record 10 of Set 4 | sawakin
# Processing Record 11 of Set 4 | leh
# Processing Record 12 of Set 4 | lagoa
# Processing Record 13 of Set 4 | zykovo
# Processing Record 14 of Set 4 | lisakovsk
# Processing Record 15 of Set 4 | flin flon
# Processing Record 16 of Set 4 | jaen
# Processing Record 17 of Set 4 | rocha
# Processing Record 18 of Set 4 | litovko
# Processing Record 19 of Set 4 | reconquista
# Processing Record 20 of Set 4 | luzhou
# Processing Record 21 of Set 4 | codrington
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | neiafu
# Processing Record 24 of Set 4 | kaitangata
# Processing Record 25 of Set 4 | vestmannaeyjar
# Processing Record 26 of Set 4 | vao
# Processing Record 27 of Set 4 | kruisfontein
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | ribeira grande
# Processing Record 30 of Set 4 | nanortalik
# Processing Record 31 of Set 4 | padang
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | nikolskoye
# Processing Record 34 of Set 4 | kathmandu
# Processing Record 35 of Set 4 | ponta delgada
# Processing Record 36 of Set 4 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 4 | hamilton
# Processing Record 40 of Set 4 | saskylakh
# Processing Record 41 of Set 4 | lompoc
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | carballo
# Processing Record 44 of Set 4 | armidale
# Processing Record 45 of Set 4 | kalmunai
# Processing Record 46 of Set 4 | kyshtovka
# Processing Record 47 of Set 4 | port lincoln
# Processing Record 48 of Set 4 | mehran
# Processing Record 49 of Set 4 | cuiluan
# Processing Record 50 of Set 4 | puerto carreno
# Processing Record 1 of Set 5 | santa vitoria do palmar
# Processing Record 2 of Set 5 | aksu
# Processing Record 3 of Set 5 | phra phutthabat
# Processing Record 4 of Set 5 | tocache
# Processing Record 5 of Set 5 | cap-aux-meules
# Processing Record 6 of Set 5 | velsk
# Processing Record 7 of Set 5 | katsuura
# Processing Record 8 of Set 5 | victoria
# Processing Record 9 of Set 5 | airai
# Processing Record 10 of Set 5 | kalabo
# Processing Record 11 of Set 5 | chuy
# Processing Record 12 of Set 5 | fairbanks
# Processing Record 13 of Set 5 | gibsons
# Processing Record 14 of Set 5 | pombas
# Processing Record 15 of Set 5 | sultanpur
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | sterling
# Processing Record 18 of Set 5 | lasa
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | san quintin
# Processing Record 21 of Set 5 | sao felix do xingu
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | port alfred
# Processing Record 24 of Set 5 | mareeba
# Processing Record 25 of Set 5 | almirante
# Processing Record 26 of Set 5 | winsum
# Processing Record 27 of Set 5 | pengcheng
# Processing Record 28 of Set 5 | sola
# Processing Record 29 of Set 5 | hambantota
# Processing Record 30 of Set 5 | tilichiki
# Processing Record 31 of Set 5 | garautha
# Processing Record 32 of Set 5 | ayorou
# Processing Record 33 of Set 5 | moyale
# Processing Record 34 of Set 5 | imbituba
# Processing Record 35 of Set 5 | lavrentiya
# Processing Record 36 of Set 5 | roros
# Processing Record 37 of Set 5 | bengkulu
# Processing Record 38 of Set 5 | tasiilaq
# Processing Record 39 of Set 5 | anadyr
# Processing Record 40 of Set 5 | ahipara
# Processing Record 41 of Set 5 | igarka
# Processing Record 42 of Set 5 | poronaysk
# Processing Record 43 of Set 5 | ayr
# Processing Record 44 of Set 5 | sidi qasim
# City not found. Skipping...
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | opuwo
# Processing Record 47 of Set 5 | dickinson
# Processing Record 48 of Set 5 | nemuro
# Processing Record 49 of Set 5 | ayan
# Processing Record 50 of Set 5 | coos bay
# Processing Record 1 of Set 6 | xining
# Processing Record 2 of Set 6 | bahia honda
# Processing Record 3 of Set 6 | zyryanka
# Processing Record 4 of Set 6 | amga
# Processing Record 5 of Set 6 | kavaratti
# Processing Record 6 of Set 6 | livani
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | channel-port aux basques
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | mapiri
# Processing Record 11 of Set 6 | ketchikan
# Processing Record 12 of Set 6 | muroto
# Processing Record 13 of Set 6 | riyadh
# Processing Record 14 of Set 6 | paamiut
# Processing Record 15 of Set 6 | never
# Processing Record 16 of Set 6 | la ronge
# Processing Record 17 of Set 6 | kahului
# Processing Record 18 of Set 6 | husavik
# Processing Record 19 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 6 | kallaste
# Processing Record 21 of Set 6 | adrar
# Processing Record 22 of Set 6 | kapuskasing
# Processing Record 23 of Set 6 | seminole
# Processing Record 24 of Set 6 | envira
# Processing Record 25 of Set 6 | chicama
# Processing Record 26 of Set 6 | masallatah
# Processing Record 27 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 6 | butte
# Processing Record 29 of Set 6 | birjand
# Processing Record 30 of Set 6 | kiunga
# Processing Record 31 of Set 6 | san ramon
# Processing Record 32 of Set 6 | serebriya
# Processing Record 33 of Set 6 | pochutla
# Processing Record 34 of Set 6 | severo-kurilsk
# Processing Record 35 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 6 | sioux city
# Processing Record 37 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 6 | bukachacha
# Processing Record 39 of Set 6 | khandbari
# Processing Record 40 of Set 6 | kaabong
# Processing Record 41 of Set 6 | klaeng
# Processing Record 42 of Set 6 | komsomolskiy
# Processing Record 43 of Set 6 | ngunguru
# Processing Record 44 of Set 6 | fortuna
# Processing Record 45 of Set 6 | marsh harbour
# Processing Record 46 of Set 6 | tulun
# Processing Record 47 of Set 6 | salalah
# Processing Record 48 of Set 6 | kashi
# Processing Record 49 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 50 of Set 6 | sukhumi
# Processing Record 1 of Set 7 | peleduy
# Processing Record 2 of Set 7 | clyde river
# Processing Record 3 of Set 7 | jurm
# Processing Record 4 of Set 7 | dolinsk
# Processing Record 5 of Set 7 | port-gentil
# Processing Record 6 of Set 7 | goderich
# Processing Record 7 of Set 7 | naples
# Processing Record 8 of Set 7 | saint-joseph
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 11 of Set 7 | fujin
# Processing Record 12 of Set 7 | faya
# Processing Record 13 of Set 7 | hailar
# Processing Record 14 of Set 7 | cap malheureux
# Processing Record 15 of Set 7 | dubrovnik
# Processing Record 16 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 7 | bow island
# Processing Record 18 of Set 7 | labuhan
# Processing Record 19 of Set 7 | grindavik
# Processing Record 20 of Set 7 | san carlos de bariloche
# Processing Record 21 of Set 7 | mao
# Processing Record 22 of Set 7 | ahuimanu
# Processing Record 23 of Set 7 | rietavas
# Processing Record 24 of Set 7 | ugoofaaru
# Processing Record 25 of Set 7 | alice springs
# Processing Record 26 of Set 7 | asau
# Processing Record 27 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | egvekinot
# Processing Record 30 of Set 7 | general cepeda
# Processing Record 31 of Set 7 | uvarovka
# Processing Record 32 of Set 7 | lazaro cardenas
# Processing Record 33 of Set 7 | cockburn town
# Processing Record 34 of Set 7 | durusu
# Processing Record 35 of Set 7 | kutum
# Processing Record 36 of Set 7 | guider
# Processing Record 37 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 7 | tawang
# Processing Record 39 of Set 7 | kantabanji
# Processing Record 40 of Set 7 | port moresby
# Processing Record 41 of Set 7 | lalibela
# Processing Record 42 of Set 7 | yarada
# Processing Record 43 of Set 7 | kandrian
# Processing Record 44 of Set 7 | atar
# Processing Record 45 of Set 7 | pyay
# Processing Record 46 of Set 7 | caohe
# Processing Record 47 of Set 7 | cayenne
# Processing Record 48 of Set 7 | dafeng
# Processing Record 49 of Set 7 | izberbash
# Processing Record 50 of Set 7 | lana
# Processing Record 1 of Set 8 | itoman
# Processing Record 2 of Set 8 | bubaque
# Processing Record 3 of Set 8 | maceio
# Processing Record 4 of Set 8 | voykove
# Processing Record 5 of Set 8 | kamiiso
# Processing Record 6 of Set 8 | colares
# Processing Record 7 of Set 8 | tiksi
# Processing Record 8 of Set 8 | nyurba
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 8 | half moon bay
# Processing Record 11 of Set 8 | abakaliki
# Processing Record 12 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 8 | wanning
# Processing Record 14 of Set 8 | panyutyne
# Processing Record 15 of Set 8 | aksum
# Processing Record 16 of Set 8 | olinda
# Processing Record 17 of Set 8 | dicabisagan
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | mersing
# Processing Record 20 of Set 8 | warmbad
# Processing Record 21 of Set 8 | namibe
# Processing Record 22 of Set 8 | kuryk
# Processing Record 23 of Set 8 | avera
# Processing Record 24 of Set 8 | bambous virieux
# Processing Record 25 of Set 8 | abu samrah
# Processing Record 26 of Set 8 | peruibe
# Processing Record 27 of Set 8 | nabire
# Processing Record 28 of Set 8 | waddan
# Processing Record 29 of Set 8 | caravelas
# Processing Record 30 of Set 8 | kavieng
# Processing Record 31 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 32 of Set 8 | tupa
# Processing Record 33 of Set 8 | indramayu
# Processing Record 34 of Set 8 | helong
# Processing Record 35 of Set 8 | batemans bay
# Processing Record 36 of Set 8 | mokobeng
# Processing Record 37 of Set 8 | shimoda
# Processing Record 38 of Set 8 | kaliganj
# Processing Record 39 of Set 8 | bay roberts
# Processing Record 40 of Set 8 | paungde
# Processing Record 41 of Set 8 | langfang
# Processing Record 42 of Set 8 | tazovskiy
# Processing Record 43 of Set 8 | sibu
# Processing Record 44 of Set 8 | aklavik
# Processing Record 45 of Set 8 | san miguel
# Processing Record 46 of Set 8 | tevaitoa
# Processing Record 47 of Set 8 | el sauzal
# Processing Record 48 of Set 8 | uyuni
# Processing Record 49 of Set 8 | antofagasta
# Processing Record 50 of Set 8 | cabo rojo
# Processing Record 1 of Set 9 | mount isa
# Processing Record 2 of Set 9 | saint-augustin
# Processing Record 3 of Set 9 | gunjur
# Processing Record 4 of Set 9 | lakes entrance
# Processing Record 5 of Set 9 | ilulissat
# Processing Record 6 of Set 9 | chihuahua
# Processing Record 7 of Set 9 | vasterhaninge
# Processing Record 8 of Set 9 | marzuq
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | taga
# Processing Record 11 of Set 9 | likasi
# Processing Record 12 of Set 9 | jacareacanga
# Processing Record 13 of Set 9 | hirara
# Processing Record 14 of Set 9 | amapa
# Processing Record 15 of Set 9 | sinnamary
# Processing Record 16 of Set 9 | san patricio
# Processing Record 17 of Set 9 | groton
# Processing Record 18 of Set 9 | bandiagara
# Processing Record 19 of Set 9 | amuntai
# Processing Record 20 of Set 9 | guerrero
# Processing Record 21 of Set 9 | palm coast
# Processing Record 22 of Set 9 | benguela
# Processing Record 23 of Set 9 | srednekolymsk
# Processing Record 24 of Set 9 | ola
# Processing Record 25 of Set 9 | mollendo
# Processing Record 26 of Set 9 | nome
# Processing Record 27 of Set 9 | temple
# Processing Record 28 of Set 9 | laguna
# Processing Record 29 of Set 9 | takayama
# Processing Record 30 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 9 | tautira
# Processing Record 32 of Set 9 | kinsale
# Processing Record 33 of Set 9 | bud
# Processing Record 34 of Set 9 | port elizabeth
# Processing Record 35 of Set 9 | shadegan
# Processing Record 36 of Set 9 | nuuk
# Processing Record 37 of Set 9 | wad rawah
# Processing Record 38 of Set 9 | ouadda
# Processing Record 39 of Set 9 | tura
# Processing Record 40 of Set 9 | bure
# Processing Record 41 of Set 9 | dalbandin
# Processing Record 42 of Set 9 | requena
# Processing Record 43 of Set 9 | ayabe
# Processing Record 44 of Set 9 | mehamn
# Processing Record 45 of Set 9 | longyearbyen
# Processing Record 46 of Set 9 | san roque
# Processing Record 47 of Set 9 | limon
# Processing Record 48 of Set 9 | soe
# Processing Record 49 of Set 9 | cheyenne
# Processing Record 50 of Set 9 | agirish
# Processing Record 1 of Set 10 | bereda
# Processing Record 2 of Set 10 | biak
# Processing Record 3 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 10 | boden
# Processing Record 5 of Set 10 | anloga
# Processing Record 6 of Set 10 | ambunti
# Processing Record 7 of Set 10 | grenville
# Processing Record 8 of Set 10 | havoysund
# Processing Record 9 of Set 10 | christchurch
# Processing Record 10 of Set 10 | tonj
# Processing Record 11 of Set 10 | nynashamn
# Processing Record 12 of Set 10 | lima
# Processing Record 13 of Set 10 | hecun
# Processing Record 14 of Set 10 | horadiz
# Processing Record 15 of Set 10 | marau
# Processing Record 16 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 17 of Set 10 | caririacu
# Processing Record 18 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 10 | sundargarh
# Processing Record 20 of Set 10 | thinadhoo
# Processing Record 21 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 10 | arlit
# Processing Record 23 of Set 10 | port blair
# Processing Record 24 of Set 10 | chara
# Processing Record 25 of Set 10 | sistranda
# Processing Record 26 of Set 10 | lumut
# Processing Record 27 of Set 10 | whitley bay
# Processing Record 28 of Set 10 | sabang
# Processing Record 29 of Set 10 | baykit
# Processing Record 30 of Set 10 | kanigoro
# Processing Record 31 of Set 10 | sur
# Processing Record 32 of Set 10 | luangwa
# Processing Record 33 of Set 10 | hammerfest
# Processing Record 34 of Set 10 | gravelbourg
# Processing Record 35 of Set 10 | arrifes
# Processing Record 36 of Set 10 | mlonggo
# Processing Record 37 of Set 10 | lensk
# Processing Record 38 of Set 10 | valpoi
# Processing Record 39 of Set 10 | nabha
# Processing Record 40 of Set 10 | banda aceh
# Processing Record 41 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 10 | invermere
# Processing Record 43 of Set 10 | sibi
# Processing Record 44 of Set 10 | hue
# Processing Record 45 of Set 10 | pecos
# Processing Record 46 of Set 10 | qandahar
# City not found. Skipping...
# Processing Record 47 of Set 10 | margate
# Processing Record 48 of Set 10 | san cristobal
# Processing Record 49 of Set 10 | intipuca
# Processing Record 50 of Set 10 | qianguo
# Processing Record 1 of Set 11 | namatanai
# Processing Record 2 of Set 11 | colac
# Processing Record 3 of Set 11 | deputatskiy
# Processing Record 4 of Set 11 | gambo
# Processing Record 5 of Set 11 | boyolangu
# Processing Record 6 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 11 | balkhash
# Processing Record 8 of Set 11 | san felipe
# Processing Record 9 of Set 11 | tabou
# Processing Record 10 of Set 11 | rusne
# Processing Record 11 of Set 11 | biltine
# Processing Record 12 of Set 11 | novoagansk
# Processing Record 13 of Set 11 | vredendal
# Processing Record 14 of Set 11 | tarrafal
# Processing Record 15 of Set 11 | enshi
# Processing Record 16 of Set 11 | houston
# Processing Record 17 of Set 11 | praia
# Processing Record 18 of Set 11 | zhanaozen
# Processing Record 19 of Set 11 | alofi
# Processing Record 20 of Set 11 | nkhata bay
# Processing Record 21 of Set 11 | kaili
# Processing Record 22 of Set 11 | pitimbu
# Processing Record 23 of Set 11 | willowmore
# Processing Record 24 of Set 11 | ambilobe
# Processing Record 25 of Set 11 | khovu-aksy
# Processing Record 26 of Set 11 | yokadouma
# Processing Record 27 of Set 11 | vostok
# Processing Record 28 of Set 11 | afogados da ingazeira
# Processing Record 29 of Set 11 | canto do buriti
# Processing Record 30 of Set 11 | zlatoustovsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | bredy
# Processing Record 32 of Set 11 | port macquarie
# Processing Record 33 of Set 11 | netanya
# Processing Record 34 of Set 11 | baryatino
# Processing Record 35 of Set 11 | norman wells
# Processing Record 36 of Set 11 | vilyuysk
# Processing Record 37 of Set 11 | touros
# Processing Record 38 of Set 11 | coquimbo
# Processing Record 39 of Set 11 | tateyama
# Processing Record 40 of Set 11 | tapalpa
# Processing Record 41 of Set 11 | chokurdakh
# Processing Record 42 of Set 11 | canutama
# Processing Record 43 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 11 | inhambane
# Processing Record 45 of Set 11 | la palma
# Processing Record 46 of Set 11 | tahta
# Processing Record 47 of Set 11 | mirnyy
# Processing Record 48 of Set 11 | banyo
# Processing Record 49 of Set 11 | ust-nera
# Processing Record 50 of Set 11 | bonfim
# Processing Record 1 of Set 12 | cauquenes
# Processing Record 2 of Set 12 | purgstall
# Processing Record 3 of Set 12 | glace bay
# Processing Record 4 of Set 12 | bethanien
# Processing Record 5 of Set 12 | west odessa
# Processing Record 6 of Set 12 | kattivakkam
# Processing Record 7 of Set 12 | wilmington island
# Processing Record 8 of Set 12 | ballina
# Processing Record 9 of Set 12 | hounde
# Processing Record 10 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 11 of Set 12 | portland
# Processing Record 12 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 12 | piacabucu
# Processing Record 14 of Set 12 | bongandanga
# Processing Record 15 of Set 12 | kachug
# Processing Record 16 of Set 12 | yibin
# Processing Record 17 of Set 12 | subang
# Processing Record 18 of Set 12 | buraydah
# Processing Record 19 of Set 12 | puerto escondido
# Processing Record 20 of Set 12 | guarapari
# Processing Record 21 of Set 12 | san rafael
# Processing Record 22 of Set 12 | freeport
# Processing Record 23 of Set 12 | santiago del estero
# Processing Record 24 of Set 12 | kemin
# Processing Record 25 of Set 12 | salinopolis
# Processing Record 26 of Set 12 | comodoro rivadavia
# Processing Record 27 of Set 12 | krasnovishersk
# Processing Record 28 of Set 12 | tommot
# Processing Record 29 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 12 | lorengau
# Processing Record 31 of Set 12 | naze
# Processing Record 32 of Set 12 | geraldton
# Processing Record 33 of Set 12 | bosaso
# Processing Record 34 of Set 12 | hohhot
# Processing Record 35 of Set 12 | samarai
# Processing Record 36 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 12 | north bend
# Processing Record 38 of Set 12 | talcahuano
# Processing Record 39 of Set 12 | sakakah
# Processing Record 40 of Set 12 | murray bridge
# Processing Record 41 of Set 12 | the valley
# Processing Record 42 of Set 12 | hami
# Processing Record 43 of Set 12 | penhold
# Processing Record 44 of Set 12 | cheremshanka
# Processing Record 45 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 12 | koronadal proper
# City not found. Skipping...
# Processing Record 47 of Set 12 | hofn
# Processing Record 48 of Set 12 | kinshasa
# Processing Record 49 of Set 12 | omboue
# Processing Record 50 of Set 12 | kofarnihon
# City not found. Skipping...
# Processing Record 1 of Set 13 | goulburn
# Processing Record 2 of Set 13 | acapulco
# Processing Record 3 of Set 13 | filingue
# Processing Record 4 of Set 13 | west wendover
# Processing Record 5 of Set 13 | nizhnyaya maktama
# Processing Record 6 of Set 13 | floriano
# Processing Record 7 of Set 13 | kousseri
# Processing Record 8 of Set 13 | yulara
# Processing Record 9 of Set 13 | dzerzhinskoye
# Processing Record 10 of Set 13 | angoche
# Processing Record 11 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 13 | arkhangelsk
# Processing Record 13 of Set 13 | panorama
# Processing Record 14 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 13 | ranau
# Processing Record 16 of Set 13 | dauriya
# Processing Record 17 of Set 13 | ternate
# Processing Record 18 of Set 13 | skalnyy
# City not found. Skipping...
# Processing Record 19 of Set 13 | narrabri
# Processing Record 20 of Set 13 | havre-saint-pierre
# Processing Record 21 of Set 13 | belokurikha
# Processing Record 22 of Set 13 | dhidhdhoo
# Processing Record 23 of Set 13 | vorukh
# Processing Record 24 of Set 13 | nizhniy kuranakh
# Processing Record 25 of Set 13 | nanchang
# Processing Record 26 of Set 13 | sao raimundo das mangabeiras
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | chegdomyn
# Processing Record 29 of Set 13 | sao joao da barra
# Processing Record 30 of Set 13 | merauke
# Processing Record 31 of Set 13 | yumen
# Processing Record 32 of Set 13 | rorvik
# Processing Record 33 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 34 of Set 13 | orotukan
# Processing Record 35 of Set 13 | karratha
# Processing Record 36 of Set 13 | haines junction
# Processing Record 37 of Set 13 | ostrovnoy
# Processing Record 38 of Set 13 | guilin
# Processing Record 39 of Set 13 | gat
# Processing Record 40 of Set 13 | divnogorsk
# Processing Record 41 of Set 13 | hinton
# Processing Record 42 of Set 13 | bocaiuva
# Processing Record 43 of Set 13 | bom jardim
# Processing Record 44 of Set 13 | damghan
# Processing Record 45 of Set 13 | fukue
# Processing Record 46 of Set 13 | kokopo
# Processing Record 47 of Set 13 | alakurtti
# Processing Record 48 of Set 13 | cozumel
# Processing Record 49 of Set 13 | ushtobe
# Processing Record 50 of Set 13 | miri
# Processing Record 1 of Set 14 | rock sound
# Processing Record 2 of Set 14 | pangnirtung
# Processing Record 3 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 14 | laurel
# Processing Record 5 of Set 14 | san mateo del mar
# Processing Record 6 of Set 14 | gorontalo
# Processing Record 7 of Set 14 | ystad
# Processing Record 8 of Set 14 | imeni tsyurupy
# Processing Record 9 of Set 14 | san luis
# Processing Record 10 of Set 14 | ceres
# Processing Record 11 of Set 14 | aden
# Processing Record 12 of Set 14 | goure
# Processing Record 13 of Set 14 | chachapoyas
# Processing Record 14 of Set 14 | balclutha
# Processing Record 15 of Set 14 | orel-izumrud
# Processing Record 16 of Set 14 | kudat
# Processing Record 17 of Set 14 | atlatlahucan
# Processing Record 18 of Set 14 | rindge
# Processing Record 19 of Set 14 | hauterive
# Processing Record 20 of Set 14 | grand-santi
# Processing Record 21 of Set 14 | kovdor
# Processing Record 22 of Set 14 | holme
# Processing Record 23 of Set 14 | yerofey pavlovich
# Processing Record 24 of Set 14 | belmonte
# Processing Record 25 of Set 14 | okhotsk
# Processing Record 26 of Set 14 | virtsu
# Processing Record 27 of Set 14 | alappuzha
# Processing Record 28 of Set 14 | bourail
# Processing Record 29 of Set 14 | grenaa
# Processing Record 30 of Set 14 | kibre mengist
# Processing Record 31 of Set 14 | tanout
# Processing Record 32 of Set 14 | chenghai
# Processing Record 33 of Set 14 | yinchuan
# Processing Record 34 of Set 14 | katherine
# Processing Record 35 of Set 14 | winnemucca
# Processing Record 36 of Set 14 | davila
# Processing Record 37 of Set 14 | xinqing
# Processing Record 38 of Set 14 | walvis bay
# Processing Record 39 of Set 14 | la asuncion
# Processing Record 40 of Set 14 | bonavista
# Processing Record 41 of Set 14 | clarence town
# Processing Record 42 of Set 14 | manaure
# Processing Record 43 of Set 14 | waipawa
# Processing Record 44 of Set 14 | rio gallegos
# Processing Record 45 of Set 14 | tra vinh
# Processing Record 46 of Set 14 | sambava
# Processing Record 47 of Set 14 | krasnoselkup
# Processing Record 48 of Set 14 | solsvik
# City not found. Skipping...
# Processing Record 49 of Set 14 | satan
# Processing Record 50 of Set 14 | port hawkesbury
# Processing Record 1 of Set 15 | itaquyry
# Processing Record 2 of Set 15 | ngaoundere
# Processing Record 3 of Set 15 | whitehorse
# Processing Record 4 of Set 15 | seguela
# Processing Record 5 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 15 | kondinskoye
# Processing Record 7 of Set 15 | osa
# Processing Record 8 of Set 15 | palpa
# Processing Record 9 of Set 15 | urdoma
# Processing Record 10 of Set 15 | sigiriya
# Processing Record 11 of Set 15 | pacifica
# Processing Record 12 of Set 15 | aljezur
# Processing Record 13 of Set 15 | kuragino
# Processing Record 14 of Set 15 | champasak
# Processing Record 15 of Set 15 | tongliao
# Processing Record 16 of Set 15 | dourbali
# Processing Record 17 of Set 15 | iquitos
# Processing Record 18 of Set 15 | sapao
# City not found. Skipping...
# Processing Record 19 of Set 15 | lavumisa
# Processing Record 20 of Set 15 | aberdeen
# Processing Record 21 of Set 15 | zinder
# Processing Record 22 of Set 15 | karabulak
# Processing Record 23 of Set 15 | matay
# Processing Record 24 of Set 15 | saint anthony
# Processing Record 25 of Set 15 | funehiki
# Processing Record 26 of Set 15 | kalanchak
# Processing Record 27 of Set 15 | mahon
# Processing Record 28 of Set 15 | sarangani
# Processing Record 29 of Set 15 | puerto baquerizo moreno
# Processing Record 30 of Set 15 | tashtyp
# Processing Record 31 of Set 15 | lata
# Processing Record 32 of Set 15 | san salvador
# Processing Record 33 of Set 15 | harer
# Processing Record 34 of Set 15 | vanavara
# Processing Record 35 of Set 15 | ekibastuz
# Processing Record 36 of Set 15 | buncrana
# Processing Record 37 of Set 15 | kingman
# Processing Record 38 of Set 15 | golden gate
# Processing Record 39 of Set 15 | digby
# Processing Record 40 of Set 15 | tolbazy
# Processing Record 41 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 15 | englewood
# Processing Record 43 of Set 15 | cabra
# Processing Record 44 of Set 15 | yar-sale
# Processing Record 45 of Set 15 | ciresu
# Processing Record 46 of Set 15 | sembe
# Processing Record 47 of Set 15 | kendari
# Processing Record 48 of Set 15 | cardston
# Processing Record 49 of Set 15 | south valley
# Processing Record 50 of Set 15 | bandarbeyla
# Processing Record 1 of Set 16 | sabha
# Processing Record 2 of Set 16 | vila franca do campo
# Processing Record 3 of Set 16 | kismayo
# Processing Record 4 of Set 16 | kaoma
# Processing Record 5 of Set 16 | orgun
# City not found. Skipping...
# Processing Record 6 of Set 16 | kavarna
# Processing Record 7 of Set 16 | primero de enero
# Processing Record 8 of Set 16 | yuanping
# Processing Record 9 of Set 16 | balabac
# Processing Record 10 of Set 16 | qidong
# Processing Record 11 of Set 16 | mumbwa
# Processing Record 12 of Set 16 | manokwari
# Processing Record 13 of Set 16 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 16 | ponca city
# Processing Record 15 of Set 16 | richards bay
# Processing Record 16 of Set 16 | hosakote
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hermanus -34.4187   19.2345     55.80        88          77
# 1         Albany  42.6001  -73.9662     64.35        94         100
# 2          Vaini -21.2000 -175.2000     75.36        73          20
# 3         Aykhal  66.0000  111.5000     78.10        30          46
# 4           Emba  48.8264   58.1442     89.49        28           4
# 5   Saint George  37.1041 -113.5841     92.62        27           1
# 6        Mataura -46.1927  168.8643     44.47        91         100
# 7  Pervomayskoye  43.9190   46.7102     83.23        47          88
# 8         Ormara  25.2088   64.6357     82.22        84          96
# 9     Pekalongan  -6.8886  109.6753     87.01        61          14
#
#    Wind Speed Current Description                 Date
# 0       10.09       broken clouds  2021-08-02 03:34:34
# 1        1.03     overcast clouds  2021-08-02 03:34:32
# 2       17.27          few clouds  2021-08-02 03:36:06
# 3       13.67    scattered clouds  2021-08-02 03:37:34
# 4        7.63           clear sky  2021-08-02 03:37:34
# 5        1.01           clear sky  2021-08-02 03:37:17
# 6        6.73          light rain  2021-08-02 03:37:34
# 7       10.71     overcast clouds  2021-08-02 03:37:35
# 8       15.17     overcast clouds  2021-08-02 03:37:35
# 9        3.87          few clouds  2021-08-02 03:37:35

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
